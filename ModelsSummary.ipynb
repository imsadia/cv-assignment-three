# %%
from keras_segmentation.models.unet import vgg_unet
import matplotlib.pyplot as plt

# Loading vgg unet model
model = vgg_unet(n_classes=12, input_height=416, input_width=608)
# Out:
# 2022-05-22 20:28:03.749121: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sadia/Computer Vision/env/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-05-22 20:28:03.749262: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-22 20:28:03.749331: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (sadia-HP-EliteBook-840-G4): /proc/driver/nvidia/version does not exist
# 2022-05-22 20:28:03.750196: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 416, 608, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 416, 608, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 416, 608, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 208, 304, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 208, 304, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 208, 304, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 104, 152, 12  0           ['block2_conv2[0][0]']
#                                 8)
#
#  block3_conv1 (Conv2D)          (None, 104, 152, 25  295168      ['block2_pool[0][0]']
#                                 6)
#
#  block3_conv2 (Conv2D)          (None, 104, 152, 25  590080      ['block3_conv1[0][0]']
#                                 6)
#
#  block3_conv3 (Conv2D)          (None, 104, 152, 25  590080      ['block3_conv2[0][0]']
#                                 6)
#
#  block3_pool (MaxPooling2D)     (None, 52, 76, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 52, 76, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 52, 76, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 52, 76, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 26, 38, 512)  0           ['block4_conv3[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 28, 40, 512)  0          ['block4_pool[0][0]']
#
#  conv2d (Conv2D)                (None, 26, 38, 512)  2359808     ['zero_padding2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 26, 38, 512)  2048       ['conv2d[0][0]']
#  alization)
#
#  up_sampling2d (UpSampling2D)   (None, 52, 76, 512)  0           ['batch_normalization[0][0]']
#
#  concatenate (Concatenate)      (None, 52, 76, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'block3_pool[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 54, 78, 768)  0          ['concatenate[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)              (None, 52, 76, 256)  1769728     ['zero_padding2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 52, 76, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 104, 152, 25  0          ['batch_normalization_1[0][0]']
#                                 6)
#
#  concatenate_1 (Concatenate)    (None, 104, 152, 38  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'block2_pool[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 106, 154, 38  0          ['concatenate_1[0][0]']
#  D)                             4)
#
#  conv2d_2 (Conv2D)              (None, 104, 152, 12  442496      ['zero_padding2d_2[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 104, 152, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 208, 304, 12  0          ['batch_normalization_2[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 208, 304, 19  0           ['up_sampling2d_2[0][0]',
#                                 2)                                'block1_pool[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 210, 306, 19  0          ['concatenate_2[0][0]']
#  D)                             2)
#
#  seg_feats (Conv2D)             (None, 208, 304, 64  110656      ['zero_padding2d_3[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 208, 304, 64  256        ['seg_feats[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 208, 304, 12  6924        ['batch_normalization_3[0][0]']
#                                 )
#
#  reshape (Reshape)              (None, 63232, 12)    0           ['conv2d_3[0][0]']
#
#  activation (Activation)        (None, 63232, 12)    0           ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 12,328,716
# Trainable params: 12,326,796
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
from keras_segmentation.models.unet import mobilenet_unet

# Loading vgg unet model
model = mobilenet_unet(n_classes=12, input_height=416, input_width=608)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 11s 1us/step
# 17235968/17225924 [==============================] - 11s 1us/step

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 416, 608, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 418, 610, 3)  0           ['input_2[0][0]']
#
#  conv1 (Conv2D)                 (None, 208, 304, 32  864         ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 208, 304, 32  128         ['conv1[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 208, 304, 32  0           ['conv1_bn[0][0]']
#                                 )
#
#  conv_pad_1 (ZeroPadding2D)     (None, 210, 306, 32  0           ['conv1_relu[0][0]']
#                                 )
#
#  conv_dw_1 (DepthwiseConv2D)    (None, 208, 304, 32  288         ['conv_pad_1[0][0]']
#                                 )
#
#  conv_dw_1_bn (BatchNormalizati  (None, 208, 304, 32  128        ['conv_dw_1[0][0]']
#  on)                            )
#
#  conv_dw_1_relu (Activation)    (None, 208, 304, 32  0           ['conv_dw_1_bn[0][0]']
#                                 )
#
#  conv_pw_1 (Conv2D)             (None, 208, 304, 64  2048        ['conv_dw_1_relu[0][0]']
#                                 )
#
#  conv_pw_1_bn (BatchNormalizati  (None, 208, 304, 64  256        ['conv_pw_1[0][0]']
#  on)                            )
#
#  conv_pw_1_relu (Activation)    (None, 208, 304, 64  0           ['conv_pw_1_bn[0][0]']
#                                 )
#
#  conv_pad_2 (ZeroPadding2D)     (None, 210, 306, 64  0           ['conv_pw_1_relu[0][0]']
#                                 )
#
#  conv_dw_2 (DepthwiseConv2D)    (None, 104, 152, 64  576         ['conv_pad_2[0][0]']
#                                 )
#
#  conv_dw_2_bn (BatchNormalizati  (None, 104, 152, 64  256        ['conv_dw_2[0][0]']
#  on)                            )
#
#  conv_dw_2_relu (Activation)    (None, 104, 152, 64  0           ['conv_dw_2_bn[0][0]']
#                                 )
#
#  conv_pw_2 (Conv2D)             (None, 104, 152, 12  8192        ['conv_dw_2_relu[0][0]']
#                                 8)
#
#  conv_pw_2_bn (BatchNormalizati  (None, 104, 152, 12  512        ['conv_pw_2[0][0]']
#  on)                            8)
#
#  conv_pw_2_relu (Activation)    (None, 104, 152, 12  0           ['conv_pw_2_bn[0][0]']
#                                 8)
#
#  conv_pad_3 (ZeroPadding2D)     (None, 106, 154, 12  0           ['conv_pw_2_relu[0][0]']
#                                 8)
#
#  conv_dw_3 (DepthwiseConv2D)    (None, 104, 152, 12  1152        ['conv_pad_3[0][0]']
#                                 8)
#
#  conv_dw_3_bn (BatchNormalizati  (None, 104, 152, 12  512        ['conv_dw_3[0][0]']
#  on)                            8)
#
#  conv_dw_3_relu (Activation)    (None, 104, 152, 12  0           ['conv_dw_3_bn[0][0]']
#                                 8)
#
#  conv_pw_3 (Conv2D)             (None, 104, 152, 12  16384       ['conv_dw_3_relu[0][0]']
#                                 8)
#
#  conv_pw_3_bn (BatchNormalizati  (None, 104, 152, 12  512        ['conv_pw_3[0][0]']
#  on)                            8)
#
#  conv_pw_3_relu (Activation)    (None, 104, 152, 12  0           ['conv_pw_3_bn[0][0]']
#                                 8)
#
#  conv_pad_4 (ZeroPadding2D)     (None, 106, 154, 12  0           ['conv_pw_3_relu[0][0]']
#                                 8)
#  conv_dw_4 (DepthwiseConv2D)    (None, 52, 76, 128)  1152        ['conv_pad_4[0][0]']
#
#  conv_dw_4_bn (BatchNormalizati  (None, 52, 76, 128)  512        ['conv_dw_4[0][0]']
#  on)
#
#  conv_dw_4_relu (Activation)    (None, 52, 76, 128)  0           ['conv_dw_4_bn[0][0]']
#
#  conv_pw_4 (Conv2D)             (None, 52, 76, 256)  32768       ['conv_dw_4_relu[0][0]']
#
#  conv_pw_4_bn (BatchNormalizati  (None, 52, 76, 256)  1024       ['conv_pw_4[0][0]']
#  on)
#
#  conv_pw_4_relu (Activation)    (None, 52, 76, 256)  0           ['conv_pw_4_bn[0][0]']
#
#  conv_pad_5 (ZeroPadding2D)     (None, 54, 78, 256)  0           ['conv_pw_4_relu[0][0]']
#
#  conv_dw_5 (DepthwiseConv2D)    (None, 52, 76, 256)  2304        ['conv_pad_5[0][0]']
#
#  conv_dw_5_bn (BatchNormalizati  (None, 52, 76, 256)  1024       ['conv_dw_5[0][0]']
#  on)
#
#  conv_dw_5_relu (Activation)    (None, 52, 76, 256)  0           ['conv_dw_5_bn[0][0]']
#
#  conv_pw_5 (Conv2D)             (None, 52, 76, 256)  65536       ['conv_dw_5_relu[0][0]']
#
#  conv_pw_5_bn (BatchNormalizati  (None, 52, 76, 256)  1024       ['conv_pw_5[0][0]']
#  on)
#
#  conv_pw_5_relu (Activation)    (None, 52, 76, 256)  0           ['conv_pw_5_bn[0][0]']
#
#  conv_pad_6 (ZeroPadding2D)     (None, 54, 78, 256)  0           ['conv_pw_5_relu[0][0]']
#
#  conv_dw_6 (DepthwiseConv2D)    (None, 26, 38, 256)  2304        ['conv_pad_6[0][0]']
#
#  conv_dw_6_bn (BatchNormalizati  (None, 26, 38, 256)  1024       ['conv_dw_6[0][0]']
#  on)
#
#  conv_dw_6_relu (Activation)    (None, 26, 38, 256)  0           ['conv_dw_6_bn[0][0]']
#
#  conv_pw_6 (Conv2D)             (None, 26, 38, 512)  131072      ['conv_dw_6_relu[0][0]']
#
#  conv_pw_6_bn (BatchNormalizati  (None, 26, 38, 512)  2048       ['conv_pw_6[0][0]']
#  on)
#
#  conv_pw_6_relu (Activation)    (None, 26, 38, 512)  0           ['conv_pw_6_bn[0][0]']
#
#  conv_pad_7 (ZeroPadding2D)     (None, 28, 40, 512)  0           ['conv_pw_6_relu[0][0]']
#
#  conv_dw_7 (DepthwiseConv2D)    (None, 26, 38, 512)  4608        ['conv_pad_7[0][0]']
#
#  conv_dw_7_bn (BatchNormalizati  (None, 26, 38, 512)  2048       ['conv_dw_7[0][0]']
#  on)
#
#  conv_dw_7_relu (Activation)    (None, 26, 38, 512)  0           ['conv_dw_7_bn[0][0]']
#
#  conv_pw_7 (Conv2D)             (None, 26, 38, 512)  262144      ['conv_dw_7_relu[0][0]']
#
#  conv_pw_7_bn (BatchNormalizati  (None, 26, 38, 512)  2048       ['conv_pw_7[0][0]']
#  on)
#
#  conv_pw_7_relu (Activation)    (None, 26, 38, 512)  0           ['conv_pw_7_bn[0][0]']
#
#  conv_pad_8 (ZeroPadding2D)     (None, 28, 40, 512)  0           ['conv_pw_7_relu[0][0]']
#
#  conv_dw_8 (DepthwiseConv2D)    (None, 26, 38, 512)  4608        ['conv_pad_8[0][0]']
#
#  conv_dw_8_bn (BatchNormalizati  (None, 26, 38, 512)  2048       ['conv_dw_8[0][0]']
#  on)
#
#  conv_dw_8_relu (Activation)    (None, 26, 38, 512)  0           ['conv_dw_8_bn[0][0]']
#
#  conv_pw_8 (Conv2D)             (None, 26, 38, 512)  262144      ['conv_dw_8_relu[0][0]']
#
#  conv_pw_8_bn (BatchNormalizati  (None, 26, 38, 512)  2048       ['conv_pw_8[0][0]']
#  on)
#
#  conv_pw_8_relu (Activation)    (None, 26, 38, 512)  0           ['conv_pw_8_bn[0][0]']
#
#  conv_pad_9 (ZeroPadding2D)     (None, 28, 40, 512)  0           ['conv_pw_8_relu[0][0]']
#
#  conv_dw_9 (DepthwiseConv2D)    (None, 26, 38, 512)  4608        ['conv_pad_9[0][0]']
#
#  conv_dw_9_bn (BatchNormalizati  (None, 26, 38, 512)  2048       ['conv_dw_9[0][0]']
#  on)
#
#  conv_dw_9_relu (Activation)    (None, 26, 38, 512)  0           ['conv_dw_9_bn[0][0]']
#
#  conv_pw_9 (Conv2D)             (None, 26, 38, 512)  262144      ['conv_dw_9_relu[0][0]']
#
#  conv_pw_9_bn (BatchNormalizati  (None, 26, 38, 512)  2048       ['conv_pw_9[0][0]']
#  on)
#
#  conv_pw_9_relu (Activation)    (None, 26, 38, 512)  0           ['conv_pw_9_bn[0][0]']
#
#  conv_pad_10 (ZeroPadding2D)    (None, 28, 40, 512)  0           ['conv_pw_9_relu[0][0]']
#
#  conv_dw_10 (DepthwiseConv2D)   (None, 26, 38, 512)  4608        ['conv_pad_10[0][0]']
#
#  conv_dw_10_bn (BatchNormalizat  (None, 26, 38, 512)  2048       ['conv_dw_10[0][0]']
#  ion)
#
#  conv_dw_10_relu (Activation)   (None, 26, 38, 512)  0           ['conv_dw_10_bn[0][0]']
#
#  conv_pw_10 (Conv2D)            (None, 26, 38, 512)  262144      ['conv_dw_10_relu[0][0]']
#
#  conv_pw_10_bn (BatchNormalizat  (None, 26, 38, 512)  2048       ['conv_pw_10[0][0]']
#  ion)
#
#  conv_pw_10_relu (Activation)   (None, 26, 38, 512)  0           ['conv_pw_10_bn[0][0]']
#
#  conv_pad_11 (ZeroPadding2D)    (None, 28, 40, 512)  0           ['conv_pw_10_relu[0][0]']
#
#  conv_dw_11 (DepthwiseConv2D)   (None, 26, 38, 512)  4608        ['conv_pad_11[0][0]']
#
#  conv_dw_11_bn (BatchNormalizat  (None, 26, 38, 512)  2048       ['conv_dw_11[0][0]']
#  ion)
#
#  conv_dw_11_relu (Activation)   (None, 26, 38, 512)  0           ['conv_dw_11_bn[0][0]']
#
#  conv_pw_11 (Conv2D)            (None, 26, 38, 512)  262144      ['conv_dw_11_relu[0][0]']
#
#  conv_pw_11_bn (BatchNormalizat  (None, 26, 38, 512)  2048       ['conv_pw_11[0][0]']
#  ion)
#
#  conv_pw_11_relu (Activation)   (None, 26, 38, 512)  0           ['conv_pw_11_bn[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 28, 40, 512)  0          ['conv_pw_11_relu[0][0]']
#  D)
#
#  conv2d (Conv2D)                (None, 26, 38, 512)  2359808     ['zero_padding2d_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 26, 38, 512)  2048       ['conv2d[0][0]']
#  alization)
#
#  up_sampling2d (UpSampling2D)   (None, 52, 76, 512)  0           ['batch_normalization[0][0]']
#
#  concatenate (Concatenate)      (None, 52, 76, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'conv_pw_5_relu[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 54, 78, 768)  0          ['concatenate[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)              (None, 52, 76, 256)  1769728     ['zero_padding2d_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 52, 76, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 104, 152, 25  0          ['batch_normalization_1[0][0]']
#                                 6)
#
#  concatenate_1 (Concatenate)    (None, 104, 152, 38  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'conv_pw_3_relu[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (None, 106, 154, 38  0          ['concatenate_1[0][0]']
#  D)                             4)
#
#  conv2d_2 (Conv2D)              (None, 104, 152, 12  442496      ['zero_padding2d_4[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 104, 152, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 208, 304, 12  0          ['batch_normalization_2[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 208, 304, 19  0           ['up_sampling2d_2[0][0]',
#                                 2)                                'conv_pw_1_relu[0][0]']
#
#  zero_padding2d_5 (ZeroPadding2  (None, 210, 306, 19  0          ['concatenate_2[0][0]']
#  D)                             2)
#
#  seg_feats (Conv2D)             (None, 208, 304, 64  110656      ['zero_padding2d_5[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 208, 304, 64  256        ['seg_feats[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 208, 304, 12  6924        ['batch_normalization_3[0][0]']
#                                 )
#
#  reshape (Reshape)              (None, 63232, 12)    0           ['conv2d_3[0][0]']
#
#  activation_49 (Activation)     (None, 63232, 12)    0           ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 6,321,292
# Trainable params: 6,304,652
# Non-trainable params: 16,640
# __________________________________________________________________________________________________
